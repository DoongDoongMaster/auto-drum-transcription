# %%
DRUM_TYPES = {
    "CC": [
        49,  # crash cymbal 1
        57,  # crash cymbal 2
        52,  # china cymbal
        55,  # splash cymbal
        51,  # ride cymbal
        59,  # ride cymbal 2
        "CC",  # crash (ddm-own)
    ],  # crash
    "OH": [
        "ohh",
        46,  # hi-hat open
        "overheads",  # drum kit data
    ],  # hi-hat open
    "CH": [
        "chh",
        42,  # hi-hat cloased
        "HH",  # closed hi-hat (ddm-own)
    ],  # hi-hat closed
    "TT": [
        "mt",
        45,  # mid tom
        47,  # mid tom
        48,  # high-mid tom
        50,  # high tom
        "toms",  # tom (drum kit data)
    ],  # tom
    "SD": [
        "sd",
        38,  # snare drum
        40,  # electric snare drum
        "snare",  # snare drum (drum kit data)
        "SD",  # snare (ddm-own)
    ],  # snare
    "KK": [
        "bd",
        35,  # bass drum
        36,  # kick drum
        "kick",  # kick (drum kit data)
        "KD",  # kick (idmt)
        "KK",  # kick (ddm-own)
    ],  # kick
}
DRUM_MAP = {}
# Iterate over the DRUM_TYPES
for drum_type, values in DRUM_TYPES.items():
    # Iterate over the values for each drum_type
    for value in values:
        # Add the mapping to the new dictionary
        DRUM_MAP[value] = drum_type

# %%
import pretty_midi

def _get_drum_track_from_mid(midi_data):
    # Find the drum track
    drum_track = next(
        (instrument for instrument in midi_data.instruments if instrument.is_drum),
        None,
    )

    if drum_track is None:
        print("No drum track found in the MIDI file.")
        return None

    return drum_track

def get_onsets_from_mid(
    midi_path: str, start: float = 0, end: float = None
):
    """
    -- MID file에서 onset 읽어오기
    """
    midi_data = pretty_midi.PrettyMIDI(midi_path)
    drum_track = _get_drum_track_from_mid(midi_data)
    onset_times = [note.start for note in drum_track.notes]
    onset_times.sort()
    return onset_times

@staticmethod
def get_onsets_instrument_from_mid(
    midi_path: str, start: float = 0, end: float = None, onset_dict={}
):
    """
    -- midi file에서 드럼 악기별로 onset을 구하는 함수

    onset_dict : {'CC':[], 'OH':[], 'CH':[], 'TT':[], 'SD':[], 'HH':[]}
    """
    midi_data = pretty_midi.PrettyMIDI(midi_path)
    drum_track = _get_drum_track_from_mid(midi_data)

    # Dictionary to store onsets for each selected drum instrument
    drum_onsets = onset_dict
    # print(drum_onsets)

    # 악기의 노트를 순회하며 onset을 찾음
    for note in drum_track.notes:
        if note.pitch in DRUM_MAP:
            drum_onsets[DRUM_MAP[note.pitch]].append(note.start)

    return drum_onsets

# %%
import pretty_midi

# midi 읽기
midi_path = "../data/test/8_rock_100_beat_4-4_1.midi"
midi_data = pretty_midi.PrettyMIDI(midi_path)
drum_track = _get_drum_track_from_mid(midi_data)

# Dictionary to store onsets for each selected drum instrument
drum_onsets = []
# print(drum_onsets)

# 악기의 노트를 순회하며 onset을 찾음
for idx, note in enumerate(drum_track.notes):
    drum_onsets.append({"pitch": note.pitch, "start": note.start})
    if note.pitch == 58:
        print(idx, "삐융")

# %%
drum_onsets
# Out:
# [{'pitch': 38, 'start': 0.0},
#  {'pitch': 22, 'start': 0.0},
#  {'pitch': 22, 'start': 0.28250000000000003},
#  {'pitch': 36, 'start': 0.30625},
#  {'pitch': 36, 'start': 0.5325},
#  {'pitch': 38, 'start': 0.58125},
#  {'pitch': 22, 'start': 0.58875},
#  {'pitch': 22, 'start': 0.8562500000000001},
#  {'pitch': 36, 'start': 0.9925},
#  {'pitch': 36, 'start': 1.12125},
#  {'pitch': 26, 'start': 1.17875},
#  {'pitch': 40, 'start': 1.17875},
#  {'pitch': 26, 'start': 1.4775},
#  {'pitch': 36, 'start': 1.485},
#  {'pitch': 38, 'start': 1.65875},
#  {'pitch': 38, 'start': 1.71},
#  {'pitch': 38, 'start': 1.8025},
#  {'pitch': 44, 'start': 1.85},
#  {'pitch': 38, 'start': 1.94875},
#  {'pitch': 48, 'start': 2.0975},
#  {'pitch': 48, 'start': 2.2475},
#  {'pitch': 44, 'start': 2.3775},
#  {'pitch': 55, 'start': 2.4},
#  {'pitch': 36, 'start': 2.4175},
#  {'pitch': 22, 'start': 2.69625},
#  {'pitch': 36, 'start': 2.8375},
#  {'pitch': 36, 'start': 2.9162500000000002},
#  {'pitch': 38, 'start': 3.02375},
#  {'pitch': 22, 'start': 3.0275},
#  {'pitch': 22, 'start': 3.31625},
#  {'pitch': 36, 'start': 3.32625},
#  {'pitch': 38, 'start': 3.46625},
#  {'pitch': 38, 'start': 3.52875},
#  {'pitch': 38, 'start': 3.58875},
#  {'pitch': 22, 'start': 3.6025},
#  {'pitch': 40, 'start': 3.76125},
#  {'pitch': 22, 'start': 3.9025000000000003},
#  {'pitch': 36, 'start': 4.05625},
#  {'pitch': 38, 'start': 4.195},
#  {'pitch': 22, 'start': 4.195},
#  {'pitch': 36, 'start': 4.36625},
#  {'pitch': 22, 'start': 4.4875},
#  {'pitch': 38, 'start': 4.5875},
#  {'pitch': 38, 'start': 4.65625},
#  {'pitch': 38, 'start': 4.7275},
#  {'pitch': 22, 'start': 4.785},
#  {'pitch': 36, 'start': 4.80375},
#  {'pitch': 22, 'start': 5.07},
#  {'pitch': 36, 'start': 5.0825000000000005},
#  {'pitch': 38, 'start': 5.36625},
#  {'pitch': 22, 'start': 5.3775},
#  {'pitch': 40, 'start': 5.51125},
#  {'pitch': 22, 'start': 5.67375},
#  {'pitch': 36, 'start': 5.8225},
#  {'pitch': 22, 'start': 5.9725},
#  {'pitch': 40, 'start': 5.97125},
#  {'pitch': 22, 'start': 6.26125},
#  {'pitch': 36, 'start': 6.26875},
#  {'pitch': 36, 'start': 6.43625},
#  {'pitch': 38, 'start': 6.5675},
#  {'pitch': 22, 'start': 6.5687500000000005},
#  {'pitch': 36, 'start': 6.7275},
#  {'pitch': 22, 'start': 6.86125},
#  {'pitch': 38, 'start': 6.97375},
#  {'pitch': 38, 'start': 7.0600000000000005},
#  {'pitch': 22, 'start': 7.18125},
#  {'pitch': 36, 'start': 7.19125},
#  {'pitch': 22, 'start': 7.4725},
#  {'pitch': 38, 'start': 7.47125},
#  {'pitch': 22, 'start': 7.765000000000001},
#  {'pitch': 38, 'start': 7.765000000000001},
#  {'pitch': 36, 'start': 7.91375},
#  {'pitch': 22, 'start': 8.0725},
#  {'pitch': 38, 'start': 8.23125},
#  {'pitch': 22, 'start': 8.38875},
#  {'pitch': 36, 'start': 8.5375},
#  {'pitch': 38, 'start': 8.6775},
#  {'pitch': 22, 'start': 8.68375},
#  {'pitch': 22, 'start': 8.965},
#  {'pitch': 36, 'start': 8.981250000000001},
#  {'pitch': 36, 'start': 9.11625},
#  {'pitch': 22, 'start': 9.27},
#  {'pitch': 36, 'start': 9.435},
#  {'pitch': 38, 'start': 9.57375},
#  {'pitch': 22, 'start': 9.5825},
#  {'pitch': 22, 'start': 9.883750000000001},
#  {'pitch': 36, 'start': 9.88625},
#  {'pitch': 36, 'start': 10.0525},
#  {'pitch': 38, 'start': 10.1925},
#  {'pitch': 22, 'start': 10.19375},
#  {'pitch': 26, 'start': 10.49125},
#  {'pitch': 36, 'start': 10.51375},
#  {'pitch': 40, 'start': 10.80125},
#  {'pitch': 26, 'start': 10.805},
#  {'pitch': 36, 'start': 11.1075}]

# %%
onset_init={v: [] for v, _ in DRUM_TYPES.items()}

# %%
import glob
e_gmd_data = glob.glob('../data/raw/e-gmd-v1.0.0/e-gmd-v1.0.0/**/*.midi', recursive=True)
no_hihat = []
for midi_file in e_gmd_data:
    # print(midi_file)
    drum_onsets = get_onsets_instrument_from_mid(midi_file, onset_dict={v: [] for v, _ in DRUM_TYPES.items()})
    chk = True
    for k, _ in DRUM_TYPES.items():
        if len(drum_onsets[k]) < 10:
            chk = False
            break
    if chk:
        print(midi_file)
# Out:
# ../data/raw/e-gmd-v1.0.0/e-gmd-v1.0.0/drummer3/session1/1_rock_105_beat_4-4_2.midi
# ../data/raw/e-gmd-v1.0.0/e-gmd-v1.0.0/drummer3/session1/1_rock_105_beat_4-4_51.midi
# ../data/raw/e-gmd-v1.0.0/e-gmd-v1.0.0/drummer3/session1/1_rock_105_beat_4-4_19.midi
# ../data/raw/e-gmd-v1.0.0/e-gmd-v1.0.0/drummer3/session1/1_rock_105_beat_4-4_18.midi
# ../data/raw/e-gmd-v1.0.0/e-gmd-v1.0.0/drummer3/session1/1_rock_105_beat_4-4_22.midi
# ../data/raw/e-gmd-v1.0.0/e-gmd-v1.0.0/drummer3/session1/1_rock_105_beat_4-4_36.midi
# ../data/raw/e-gmd-v1.0.0/e-gmd-v1.0.0/drummer3/session1/1_rock_105_beat_4-4_4.midi
# ../data/raw/e-gmd-v1.0.0/e-gmd-v1.0.0/drummer3/session1/1_rock_105_beat_4-4_54.midi
# ../data/raw/e-gmd-v1.0.0/e-gmd-v1.0.0/drummer3/session1/1_rock_105_beat_4-4_15.midi
# ../data/raw/e-gmd-v1.0.0/e-gmd-v1.0.0/drummer3/session1/1_rock_105_beat_4-4_25.midi
# ../data/raw/e-gmd-v1.0.0/e-gmd-v1.0.0/drummer3/session1/1_rock_105_beat_4-4_42.midi
# ../data/raw/e-gmd-v1.0.0/e-gmd-v1.0.0/drummer3/session1/1_rock_105_beat_4-4_43.midi
# ../data/raw/e-gmd-v1.0.0/e-gmd-v1.0.0/drummer3/session1/1_rock_105_beat_4-4_3.midi
# ../data/raw/e-gmd-v1.0.0/e-gmd-v1.0.0/drummer3/session1/1_rock_105_beat_4-4_37.midi
# ../data/raw/e-gmd-v1.0.0/e-gmd-v1.0.0/drummer3/session1/1_rock_105_beat_4-4_35.midi
# ../data/raw/e-gmd-v1.0.0/e-gmd-v1.0.0/drummer3/session1/1_rock_105_beat_4-4_11.midi
# ../data/raw/e-gmd-v1.0.0/e-gmd-v1.0.0/drummer3/session1/1_rock_105_beat_4-4_14.midi
# ../data/raw/e-gmd-v1.0.0/e-gmd-v1.0.0/drummer3/session1/1_rock_105_beat_4-4_56.midi
# ../data/raw/e-gmd-v1.0.0/e-gmd-v1.0.0/drummer3/session1/1_rock_105_beat_4-4_1.midi
# ../data/raw/e-gmd-v1.0.0/e-gmd-v1.0.0/drummer3/session1/1_rock_105_beat_4-4_52.midi
# ../data/raw/e-gmd-v1.0.0/e-gmd-v1.0.0/drummer3/session1/1_rock_105_beat_4-4_34.midi
# ../data/raw/e-gmd-v1.0.0/e-gmd-v1.0.0/drummer3/session1/1_rock_105_beat_4-4_41.midi
# ../data/raw/e-gmd-v1.0.0/e-gmd-v1.0.0/drummer3/session1/1_rock_105_beat_4-4_28.midi
# ../data/raw/e-gmd-v1.0.0/e-gmd-v1.0.0/drummer3/session1/1_rock_105_beat_4-4_10.midi
# ../data/raw/e-gmd-v1.0.0/e-gmd-v1.0.0/drummer3/session1/1_rock_105_beat_4-4_24.midi
# ../data/raw/e-gmd-v1.0.0/e-gmd-v1.0.0/drummer3/session1/1_rock_105_beat_4-4_53.midi
# ../data/raw/e-gmd-v1.0.0/e-gmd-v1.0.0/drummer3/session1/1_rock_105_beat_4-4_26.midi
# ../data/raw/e-gmd-v1.0.0/e-gmd-v1.0.0/drummer3/session1/1_rock_105_beat_4-4_16.midi
# ../data/raw/e-gmd-v1.0.0/e-gmd-v1.0.0/drummer3/session1/1_rock_105_beat_4-4_5.midi
# ../data/raw/e-gmd-v1.0.0/e-gmd-v1.0.0/drummer3/session1/1_rock_105_beat_4-4_13.midi
# ../data/raw/e-gmd-v1.0.0/e-gmd-v1.0.0/drummer3/session1/1_rock_105_beat_4-4_44.midi
# ../data/raw/e-gmd-v1.0.0/e-gmd-v1.0.0/drumm
#      34
#      35     onset_dict : {'CC':[], 'OH':[], 'CH':[], 'TT':[], 'SD':[], 'HH':[]}
#      36     """
# ---> 37     midi_data = pretty_midi.PrettyMIDI(midi_path)
#      38     drum_track = _get_drum_track_from_mid(midi_data)
#      40     # Dictionary to store onsets for each selected drum instrument
#
# File ~/anaconda3/envs/drum/lib/python3.11/site-packages/pretty_midi/pretty_midi.py:63, in PrettyMIDI.__init__(self, midi_file, resolution, initial_tempo)
#      59 if midi_file is not None:
#      60     # Load in the MIDI data using the midi module
#      61     if isinstance(midi_file, six.string_types):
#      62         # If a string was given, pass it as the string filename
# ---> 63         midi_data = mido.MidiFile(filename=midi_file)
#      64     else:
#      65         # Otherwise, try passing it in as a file pointer
#      66         midi_data = mido.MidiFile(file=midi_file)
#
# File ~/anaconda3/envs/drum/lib/python3.11/site-packages/mido/midifiles/midifiles.py:325, in MidiFile.__init__(self, filename, file, type, ticks_per_beat, charset, debug, clip, tracks)
#     322 # merge tracks at load time to prevent timing error on
#     323 # first call to __iter__()
#     324 if self.type != 2:
# --> 325     self.merged_track = merge_tracks(self.tracks)
#
# File ~/anaconda3/envs/drum/lib/python3.11/site-packages/mido/midifiles/tracks.py:118, in merge_tracks(tracks)
#     114     messages.extend(_to_abstime(track))
#     116 messages.sort(key=lambda msg: msg.time)
# --> 118 return MidiTrack(fix_end_of_track(_to_reltime(messages)))
#
# File ~/anaconda3/envs/drum/lib/python3.11/site-packages/mido/midifiles/tracks.py:92, in fix_end_of_track(messages)
#      88 # Accumulated delta time from removed end of track messages.
#      89 # This is added to the next message.
#      90 accum = 0
# ---> 92 for msg in messages:
#      93     if msg.type == 'end_of_track':
#      94         accum += msg.time
#
# File ~/anaconda3/envs/drum/lib/python3.11/site-packages/mido/midifiles/tracks.py:80, in _to_reltime(messages)
#      78 for msg in messages:
#      79     delta = msg.time - now
# ---> 80     yield msg.copy(time=delta)
#      81     now = msg.time
#
# File ~/anaconda3/envs/drum/lib/python3.11/site-packages/mido/messages/messages.py:142, in Message.copy(self, **overrides)
#     140 msgdict = vars(self).copy()
#     141 msgdict.update(overrides)
# --> 142 check_msgdict(msgdict)
#     143 return self.__class__(**msgdict)
#
# File ~/anaconda3/envs/drum/lib/python3.11/site-packages/mido/messages/checks.py:102, in check_msgdict(msgdict)
#      98 if name not in spec['attribute_names']:
#      99     raise ValueError(
#     100         '{} message has no attribute {}'.format(spec['type'], name))
# --> 102 check_value(name, value)
#
# File ~/anaconda3/envs/drum/lib/python3.11/site-packages/mido/messages/checks.py:89, in check_value(name, value)
#      88 def check_value(name, value):
# ---> 89     _CHECKS[name](value)
#
# File ~/anaconda3/envs/drum/lib/python3.11/site-packages/mido/messages/checks.py:64, in check_time(time)
#      60     elif not 0 <= value <= 127:
#      61         raise ValueError('data byte must be in range 0..127')
# ---> 64 def check_time(time):
#      65     if not isinstance(time, Real):
#      66         raise TypeError('time must be int or float')
#
# KeyboardInterrupt:

# %%
